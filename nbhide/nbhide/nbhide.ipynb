# %% [markdown]
# # `nblayout`: Hide/Show Cells
#
# Here is a simple way to control code cell visibility.
#
# To get started, install `nbhide` using `pip`.

# %%
# !pip install --upgrade --force-reinstall --user git+git://github.com/callysto/nbplus.git@nbhide#egg=nbhide\&subdirectory=nbhide

# %%
import nbhide.nbhide

# %% [markdown]
# This adds a button (<img style="display: inline-block;" width="18" height="18" src="https://ionicons.com/ionicons/svg/md-eye-off.svg"></img>) at the top-right of the menubar.
#
# Click this button to toggle the visibility of any hidden cells (<img style="display: inline-block;" width="18" height="18" src="https://ionicons.com/ionicons/svg/md-eye.svg"></img>).
#
# Click it again (<img style="display: inline-block;" width="18" height="18" src="https://ionicons.com/ionicons/svg/md-eye-off.svg"></img>) to make those cells go away.
#
# Cells that are hidden are gently shaded. All cells still have visible indexing (`In [i]`), and outputs are preserved.

# %%
# %%hide
# %matplotlib inline
# from numpy import exp, arange
# from pylab import meshgrid, cm, imshow, contour, clabel, colorbar, axis, show
# from mpl_toolkits.mplot3d import Axes3D
# from matplotlib import cm
# from matplotlib.ticker import LinearLocator, FormatStrFormatter
# import matplotlib.pyplot as plt
#
# def z_func(x,y): return (1-(x**2+y**3))*exp(-(x**2+y**2)/2)
#
# x = arange(-3.0,3.0,0.1)
# y = arange(-3.0,3.0,0.1)
# X,Y = meshgrid(x, y)
# Z = z_func(X, Y)
#
# fig = plt.figure()
# ax = fig.gca(projection='3d')
# surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
#                        cmap=cm.RdBu,linewidth=0, antialiased=False)
#
# ax.zaxis.set_major_locator(LinearLocator(10))
# ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
#
# fig.colorbar(surf, shrink=0.5, aspect=5)
# plt.show()

# %% [markdown]
# [//]: # (This may be the most platform independent comment)
#
# **Future**: Some may want to control the visibility of Markdown cells, or MathJax. There isn't a clear way to do this effectively, and should be explored.
#
# ---
#
# ### Acknowledgements
#
# 1. [This has nice information on the InteractiveShell class.](https://ipython-books.github.io/14-creating-an-ipython-extension-with-custom-magic-commands/)
# 2. [It's handy being able to select individual cells with JavaScript.](https://stackoverflow.com/questions/39613822/how-to-select-current-cell-with-javascript-in-jupyter)
# 3. [I borrowed the `matplotlib` sample above from here.](https://glowingpython.blogspot.com/2012/01/how-to-plot-two-variable-functions-with.html)
# 4. [I stumbled upon a neat way to deselect all text in the browser window.](https://stackoverflow.com/questions/6562727/is-there-a-function-to-deselect-all-text-using-javascript)
# 5. [I needed some inline SVG to use those icons in Markdown.](https://stackoverflow.com/questions/9201756/how-to-put-img-inline-with-text)
#
# ---
